# %% [markdown]
# # 01 — Explore the dataset (MixedWM38 or synthetic)

# %%
import numpy as np
from waferlens.data.mixedwm38 import load_npz, BASE_CLASSES
# Point at the real npz if you have it, else the synthetic sample:
d = load_npz('data/synthetic_sample.npz')
print('maps:', d.X.shape, '| labels:', d.Y.shape)
print('per-class positives:', dict(zip(BASE_CLASSES, d.Y.sum(0).astype(int))))
print('label cardinality (defects per wafer):', d.Y.sum(1).mean().round(2))
